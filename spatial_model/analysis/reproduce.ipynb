# %% [markdown]
# # Analysis of centroid's trajectory
# ## Reproduce Vivek's results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %% [markdown]
# ## 2 targets

# %%
# display parameters
text_file = open("../output/reproduce/parameters_2_targets.txt")
file_content = text_file.read()
print(file_content)
text_file.close()

df_cen = pd.read_csv('../output/reproduce/centroid_2_targets.txt', sep='\t')
df_tar = pd.read_csv('../output/reproduce/targets_2_targets.txt', sep='\t')

fig, ax = plt.subplots(figsize=(7, 7))

for i in range(df_cen.replicate.max()+1):
    plt.plot(df_cen.loc[df_cen.replicate==i,:].x, df_cen.loc[df_cen.replicate==i,:].y, c='black', alpha=0.3)

plt.scatter(df_tar.loc[df_tar.id==0,:].x, df_tar.loc[df_tar.id==0,:].y, c='r', s=100)
plt.scatter(df_tar.loc[df_tar.id==1,:].x, df_tar.loc[df_tar.id==1,:].y, c='r', s=100)

# set x and y labels as x and y
plt.xlabel('X (a.u.)', fontsize=16)
plt.ylabel('Y (a.u.)', fontsize=16)

# set title
plt.title('(A)', fontsize=20)

# set tick label size
ax.tick_params(axis='both', which='major', labelsize=14)

# set same scale for x and y
plt.axis('equal')

# save figure in pdf dpi 100
plt.savefig('../img/2_targets_prop.pdf', dpi=100, bbox_inches='tight')
# Out:
# total_agents	60
# number_of_cues	2
# informed_group_size	30
# num_replicates	100
# num_timesteps	10000
# time step_inc	0.1
# angular_error_sd	0.0
# max_turning_rate	2
# speed	1.0
# angular_thresh	0.3490658503988659
# set_omega	0.3
# omega_inc	0.012
# omega_dec	0.0008
# omega_max	0.4
# max_angle	1.0471975511965976
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 3 targets

# %%
# display parameters
text_file = open("../output/reproduce/parameters_3_targets.txt")
file_content = text_file.read()
print(file_content)
text_file.close()

df_cen = pd.read_csv('../output/reproduce/centroid_3_targets.txt', sep='\t')
df_tar = pd.read_csv('../output/reproduce/targets_3_targets.txt', sep='\t')

fig, ax = plt.subplots(figsize=(7, 7))

for i in range(df_cen.replicate.max()+1):
    plt.plot(df_cen.loc[df_cen.replicate==i,:].x, df_cen.loc[df_cen.replicate==i,:].y, c='black', alpha=0.3)

plt.scatter(df_tar.loc[df_tar.id==0,:].x, df_tar.loc[df_tar.id==0,:].y, c='r', s=100)
plt.scatter(df_tar.loc[df_tar.id==1,:].x, df_tar.loc[df_tar.id==1,:].y, c='r', s=100)
plt.scatter(df_tar.loc[df_tar.id==2,:].x, df_tar.loc[df_tar.id==2,:].y, c='r', s=100)

plt.title('(B)', fontsize=20)

# set x and y labels as x and y
plt.xlabel('X (a.u.)', fontsize=16)
plt.ylabel('Y (a.u.)', fontsize=16)

# set tick label size
ax.tick_params(axis='both', which='major', labelsize=14)

# set same scale for x and y
plt.axis('equal')

# save figure in pdf dpi 100
plt.savefig('../img/3_targets_prop.pdf', dpi=100, bbox_inches='tight')
# Out:
# total_agents	60
# number_of_cues	3
# informed_group_size	20
# num_replicates	100
# num_timesteps	10000
# time step_inc	0.1
# angular_error_sd	0.0
# max_turning_rate	2
# speed	1.0
# angular_thresh	0.3490658503988659
# set_omega	0.3
# omega_inc	0.012
# omega_dec	0.0008
# omega_max	0.4
# max_angle	1.0471975511965976
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 4 targets

# %%
# display parameters
text_file = open("../output/reproduce/parameters_4_targets.txt")
file_content = text_file.read()
print(file_content)
text_file.close()

df_cen = pd.read_csv('../output/reproduce/centroid_4_targets.txt', sep='\t')
df_tar = pd.read_csv('../output/reproduce/targets_4_targets.txt', sep='\t')

fig, ax = plt.subplots(figsize=(7, 7))

for i in range(df_cen.replicate.max()+1):
    plt.plot(df_cen.loc[df_cen.replicate==i,:].x, df_cen.loc[df_cen.replicate==i,:].y, c='black', alpha=0.3)

plt.scatter(df_tar.loc[df_tar.id==0,:].x, df_tar.loc[df_tar.id==0,:].y, c='r', s=100)
plt.scatter(df_tar.loc[df_tar.id==1,:].x, df_tar.loc[df_tar.id==1,:].y, c='r', s=100)
plt.scatter(df_tar.loc[df_tar.id==2,:].x, df_tar.loc[df_tar.id==2,:].y, c='r', s=100)
plt.scatter(df_tar.loc[df_tar.id==3,:].x, df_tar.loc[df_tar.id==3,:].y, c='r', s=100)

# set x and y labels as x and y
plt.xlabel('X (a.u.)', fontsize=16)
plt.ylabel('Y (a.u.)', fontsize=16)

plt.title('(C)', fontsize=20)

# set tick label size
ax.tick_params(axis='both', which='major', labelsize=14)

# set same scale for x and y
plt.axis('equal')

# save figure in pdf dpi 100
plt.savefig('../img/4_targets_prop.pdf', dpi=100, bbox_inches='tight')
# Out:
# total_agents	60
# number_of_cues	4
# informed_group_size	15
# num_replicates	100
# num_timesteps	10000
# time step_inc	0.1
# angular_error_sd	0.0
# max_turning_rate	2
# speed	1.0
# angular_thresh	0.3490658503988659
# set_omega	0.3
# omega_inc	0.012
# omega_dec	0.0008
# omega_max	0.4
# max_angle	1.0471975511965976
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
# display parameters
text_file = open("../output/parameters_namefile.txt")
file_content = text_file.read()
print(file_content)
text_file.close()

df_cen = pd.read_csv('../output/centroid_namefile.txt', sep='\t')
df_tar = pd.read_csv('../output/targets_namefile.txt', sep='\t')

fig, ax = plt.subplots(figsize=(7, 5))

for i in range(df_cen.replicate.max()+1):
    plt.plot(df_cen.loc[df_cen.replicate==i,:].x, df_cen.loc[df_cen.replicate==i,:].y, c='black', alpha=0.3)

plt.scatter(df_tar.loc[df_tar.id==0,:].x, df_tar.loc[df_tar.id==0,:].y, c='r', s=100)
plt.scatter(df_tar.loc[df_tar.id==1,:].x, df_tar.loc[df_tar.id==1,:].y, c='r', s=100)
#set same scale on x and y axis
ax.set_aspect('equal', 'box')
# Out:
# total_agents	60
# number_of_cues	2
# informed_group_size	30
# num_replicates	30
# num_timesteps	10000
# time step_inc	0.1
# angular_error_sd	0.0
# max_turning_rate	2
# speed	1.0
# beta	100000.0
# angular_thresh	0.3490658503988659
# set_omega	0.3
# omega_inc	0.012
# omega_dec	0.0008
# omega_max	0.4
# max_angle	0.3141592653589793
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
